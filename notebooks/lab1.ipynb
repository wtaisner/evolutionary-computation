# %%
import time
import numpy as np

from src.visualization import plot_result
from src.algorithms import RandomTSP, NearestNeighbourTSP

# %%
nodes_path = '../data/TSPA.csv'
nodes = np.genfromtxt(nodes_path, dtype=int, delimiter=';')

# %%
randomTSP = RandomTSP('../data/TSPA.csv')
start = time.time()
dist, path = randomTSP.run_algorithm(0)
print(time.time() - start)
# Out:
# 0.0003619194030761719

# %%
plot_result(nodes, path, dist)

# %%
nnTSP = NearestNeighbourTSP('../data/TSPA.csv')
start = time.time()
dist, path = nnTSP.run_algorithm(0)
print(time.time() - start)
# Out:
# 0.002361297607421875

# %%
plot_result(nodes, path, dist)
